# %% [markdown]
# # Origin of Pandas
# The Pandas library originated with Wes McKinney in 2008

# %% [markdown]
# # **Pandas Series**
#
# A Series is a one-dimensional labeled array capable of holding any data type . The axis labels are collectively called the index .

# %%
#---Creating Series---
# There are Multiple ways to create a pandas Series .
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
dict = {'A':10,'B':20,'C':30}

# %%
pd.Series(data=my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dict)
# Out:
# A    10
# B    20
# C    30
# dtype: int64
